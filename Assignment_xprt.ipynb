# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
import missingno as msna

# %% [markdown]
# lets load the data and see the features available in each dataset.

# %%
storeA_customer = pd.read_excel(r"C:\Users\indra\Downloads\releaseMyAd - DATA SCIENCE ASSIGNMENT.xlsx", sheet_name='STORE A - CUSTOMER LIST')

# %%
storeA_transactions = pd.read_excel(r"C:\Users\indra\Downloads\releaseMyAd - DATA SCIENCE ASSIGNMENT.xlsx", sheet_name="STORE A - TRANSACTIONS")

# %%
storeA_products = pd.read_excel(r"C:\Users\indra\Downloads\releaseMyAd - DATA SCIENCE ASSIGNMENT.xlsx", sheet_name="STORE A - PRODUCTS")

# %%
storeB_customer = pd.read_excel(r"C:\Users\indra\Downloads\releaseMyAd - DATA SCIENCE ASSIGNMENT.xlsx", sheet_name='STORE B - CUSTOMER LIST')

# %%
storeB_transactions = pd.read_excel(r"C:\Users\indra\Downloads\releaseMyAd - DATA SCIENCE ASSIGNMENT.xlsx", sheet_name="STORE B - TRANSACTIONS")

# %%
storeB_products = pd.read_excel(r"C:\Users\indra\Downloads\releaseMyAd - DATA SCIENCE ASSIGNMENT.xlsx", sheet_name="STORE B - PRODUCTS")

# %%
storeA_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   First Name               395 non-null    object
#  1   Last Name                402 non-null    object
#  2   Email                    114 non-null    object
#  3   Accepts Email Marketing  402 non-null    object
#  4   Company                  0 non-null      float64
#  5   Address1                 400 non-null    object
#  6   Address2                 210 non-null    object
#  7   City                     400 non-null    object
#  8   Province                 400 non-null    object
#  9   Province Code            400 non-null    object
#  10  Country                  400 non-null    object
#  11  Country Code             400 non-null    object
#  12  Zip                      400 non-null    float64
#  13  Phone                    400 non-null    object
# ...

# %%
msna.matrix(storeA_customer)
# Out:
# <AxesSubplot: >

# %%
msna.bar(storeA_customer)
# Out:
# <AxesSubplot: >

# %%
storeA_customer.shape
# Out:
# (402, 20)

# %%
storeA_customer.head(10)
# Out:
#   First Name Last Name                          Email Accepts Email Marketing  \
# 0      Lehar     Gupta                            NaN                      no
# 1          N   Lakshmi                            NaN                      no
# 2     Shiven      Jain                            NaN                      no
# 3    Preethi     Dilip       preethidilip87@email.com                      no
# 4     Rachna     Gupta  rachnaguptaeduhaven@email.com                      no
# 5    Vandana    Shenoy                            NaN                      no
# 6   Mejentha   Raveesh       mejenta.ravish@email.com                      no
# 7       Juhi    Kamdar                            NaN                      no
# 8     Sonali    Jasthi                            NaN                      no
# 9    Radhika    Mitter                            NaN                      no
#
#    Company                                           Address1  \
# ...

# %%
storeA_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         587 non-null    object
#  1   Email                        195 non-null    object
#  2   Financial Status             497 non-null    object
#  3   Paid at                      274 non-null    object
#  4   Fulfillment Status           497 non-null    object
#  5   Fulfilled at                 2 non-null      object
#  6   Accepts Marketing            497 non-null    object
#  7   Currency                     497 non-null    object
#  8   Subtotal                     497 non-null    float64
#  9   Shipping                     497 non-null    float64
#  10  Taxes                        497 non-null    float64
#  11  Total                        497 non-null    float64
#  12  Discount Code                14 non-null     object
# ...

# %%
storeA_transactions.head()
# Out:
#     Name                          Email Financial Status  \
# 0  #1499                            NaN             paid
# 1  #1498        shreyasarda96@gmail.com             paid
# 2  #1497                            NaN             paid
# 3  #1496                            NaN             paid
# 4  #1495  rachnaguptaeduhaven@gmail.com             paid
#
#                      Paid at Fulfillment Status Fulfilled at  \
# 0  2021-08-03 23:04:07 +0530        unfulfilled          NaN
# 1  2021-08-03 21:16:53 +0530        unfulfilled          NaN
# 2  2021-08-03 15:11:28 +0530        unfulfilled          NaN
# 3  2021-08-03 13:38:32 +0530        unfulfilled          NaN
# 4  2021-08-02 19:41:54 +0530        unfulfilled          NaN
#
#   Accepts Marketing Currency  Subtotal  Shipping  ...  Tax 5 Name  \
# 0                no      INR    1700.0     300.0  ...         NaN
# 1                no      INR    1800.0     200.0  ...         NaN
# ...

# %%
storeA_transactions["Billing Province Name"].value_counts()
# Out:
# Karnataka        148
# West Bengal      122
# Maharashtra       91
# Rajasthan         88
# Telangana         21
# Delhi             13
# Haryana            9
# Uttar Pradesh      1
# Dubai              1
# Texas              1
# Name: Billing Province Name, dtype: int64

# %%
storeA_transactions.loc[storeA_transactions["Billing Province Name"] == "Karnataka","Financial Status"].value_counts()
# Out:
# paid       92
# pending    56
# Name: Financial Status, dtype: int64

# %%
plt.figure(figsize=(20, 20))
sns.kdeplot(storeA_customer["Total Spent"])
# Out:
# <AxesSubplot: xlabel='Total Spent', ylabel='Density'>

# %%
storeA_customer["Total Spent"].mean()
# Out:
# 2842.332089552239

# %%
storeA_customer['Total Spent'].quantile([0, 0.25, 0.50, 0.75, 0.99])
# Out:
# 0.00        0.00
# 0.25     1700.00
# 0.50     1900.00
# 0.75     2400.00
# 0.99    21770.82
# Name: Total Spent, dtype: float64

# %%
print(storeA_customer["Total Spent"].min())
print(storeA_customer["Total Spent"].max())
# Out:
# 0.0
# 159663.5

# %%
sns.boxplot(storeA_customer["Total Spent"])
# Out:
# <AxesSubplot: >

# %%
storeA_customer["City"].value_counts()
# Out:
# Bangalore                80
# Jaipur                   68
# Bengaluru                59
# Pune                     44
# Mumbai                   39
# Kolkata                  27
# Hyderabad                23
# New Delhi                12
# Delhi                     5
# Gurugram                  5
# Banglore                  3
# jaipur                    3
# Faridabad                 3
# South Presidency          3
# New delhi                 2
# PUNE                      2
# bangalore                 2
# Gurgaon                   2
# new delhi                 1
# Thiruvalla                1
# Kolka                     1
# jsjsj                     1
# kOLKATA                   1
# kolkata                   1
# KOLKATA                   1
# Jaiput                    1
# Poona                     1
# Punr                      1
# Bangalore HQ              1
# Jaipur City               1
# Airtel Andhra Pradesh     1
# BARC COLONY MUMBAI        1
# Noida                     1
# ...

# %%
storeA_transactions["Shipping Province Name"].value_counts()
# Out:
# Karnataka      151
# Maharashtra     95
# West Bengal     93
# Rajasthan       87
# Telangana       23
# Delhi           11
# Haryana          9
# Name: Shipping Province Name, dtype: int64

# %%
storeA_transactions.shape
# Out:
# (587, 74)

# %%
msna.bar(storeA_transactions)
# Out:
# <AxesSubplot: >

# %%
storeB_transactions["Shipping Province Name"].value_counts()
# Out:
# West Bengal    6
# Maharashtra    4
# Karnataka      4
# Haryana        3
# Tamil Nadu     3
# Rajasthan      2
# Telangana      2
# New Jersey     2
# Texas          1
# Kerala         1
# Kansas         1
# Michigan       1
# Name: Shipping Province Name, dtype: int64

# %%
storeB_transactions["Billing Province Name"].value_counts()
# Out:
# West Bengal    6
# Maharashtra    4
# Karnataka      4
# Tamil Nadu     3
# Rajasthan      2
# Telangana      2
# New Jersey     2
# Kerala         2
# Haryana        2
# Texas          1
# Kansas         1
# Michigan       1
# Name: Billing Province Name, dtype: int64

# %% [markdown]
# So can see that for both Store A and B a lot of customers are from West Bengal, Maharastra and Karnataka.

# %%
storeB_customer.columns
# Out:
# Index(['First Name', 'Last Name', 'Email', 'Accepts Email Marketing',
#        'Company', 'Address1', 'Address2', 'City', 'Province', 'Province Code',
#        'Country', 'Country Code', 'Zip', 'Phone', 'Accepts SMS Marketing',
#        'Total Spent', 'Total Orders', 'Tags', 'Note', 'Tax Exempt'],
#       dtype='object')

# %%
print("Total spent mean",end="->")
print(storeB_customer.loc[storeB_customer["Total Spent"] != 0,"Total Spent"].mean())
print("Total spent median", end="->")
print(storeB_customer.loc[storeB_customer["Total Spent"] != 0, "Total Spent"].quantile(0.50))
# Out:
# Total spent mean->15604.592592592593
# Total spent median->16100.0

# %%
sns.histplot(storeB_customer.loc[(storeB_customer["Total Spent"] != 0), "Total Spent"], kde=True,color="black")
# Out:
# <AxesSubplot: xlabel='Total Spent', ylabel='Count'>

# %%
upper_fence = storeA_customer["Total Spent"].quantile(0.99)
j = storeA_customer.loc[storeA_customer["Total Spent"]<=upper_fence, "Total Spent"]
sns.histplot((j[j != 0]))
# Out:
# <AxesSubplot: xlabel='Total Spent', ylabel='Count'>

# %%
j[j!=0].median()
# Out:
# 2000.0

# %% [markdown]
# Customers in store A generally spend around 2000, while in store B around 15000
